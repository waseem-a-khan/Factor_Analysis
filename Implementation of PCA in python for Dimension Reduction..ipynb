# %%
 pip install sklearn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'C:\Users\Waseem' is not recognized as an internal or external command,
# operable program or batch file.

# %%
Collecting sklearn
  Using cached https://files.pythonhosted.org/packages/1e/7a/dbb3be0ce9bd5c8b7e3d87328e79063f8b263b2b1bfa4774cb1147bfcd3f/sklearn-0.0.tar.gz
Requirement already satisfied: scikit-learn in c:\users\waseem akram khan\anaconda3\lib\site-packages (from sklearn) (0.21.3)
Requirement already satisfied: numpy>=1.11.0 in c:\users\waseem akram khan\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.16.5)
Requirement already satisfied: scipy>=0.17.0 in c:\users\waseem akram khan\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.3.1)
Requirement already satisfied: joblib>=0.11 in c:\users\waseem akram khan\anaconda3\lib\site-packages (from scikit-learn->sklearn) (0.13.2)
Building wheels for collected packages: sklearn
  Building wheel for sklearn (setup.py) ... done
  Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1321 sha256=2c6060e27655b52bd1c4c17070f3549ca1f1fcc047916be7b64cc94f6251ce02
  Stored in directory: C:\Users\Waseem Akram Khan\AppData\Local\pip\Cache\wheels\76\03\bb\589d421d27431bcd2c6da284d5f2286c8e3b2ea3cf1594c074
Successfully built sklearn
Installing collected packages: sklearn
Successfully installed sklearn-0.0

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn import datasets,metrics
from sklearn.model_selection import train_test_split

# %%
import pandas as pd
df1=pd.read_csv("Desktop\COVID.csv")
df1.head(2)
# Out:
#                                         sha source_x  \
# 0  c630ebcdf30652f0422c3ec12a00b50241dc9bd9      CZI
# 1  53eccda7977a31e3d0f565c884da036b1e85438e      CZI
#
#                                                title  \
# 0  Angiotensin-converting enzyme 2 (ACE2) as a SA...
# 1  Comparative genetic analysis of the novel coro...
#
#                           doi pmcid   pubmed_id   license abstract  \
# 0  10.1007/s00134-020-05985-9   NaN  32125455.0  cc-by-nc      NaN
# 1   10.1038/s41421-020-0147-1   NaN         NaN     cc-by      NaN
#
#   publish_time                                            authors  \
# 0         2020  Zhang, Haibo; Penninger, Josef M.; Li, Yimin; ...
# 1         2020  Cao, Yanan; Li, Lin; Feng, Zhimin; Wan, Shengq...
#
#               journal  Microsoft Academic Paper ID WHO #Covidence  \
# 0  Intensive Care Med                 2.002765e+09          #3252
# 1      Cell Discovery                 3.003431e+09          #1861
#
#   has_full_text
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaled=scaler.fit_transform(df5)
X_scaled
# Out:
# array([[-0.02460518, -1.36275212],
#        [-0.03081768, -5.06443617],
#        [-0.02460556,  0.67331856],
#        [-0.02842798, -0.09658186],
#        [-0.02780218,  0.66704227],
#        [-0.03165639,  0.18618234],
#        [-0.0269078 ,  0.24381704],
#        [-0.02343335,  0.67337673],
#        [-0.02938112,  0.67207286],
#        [-0.04578886,  0.66637058],
#        [-0.03836387,  0.67120291],
#        [19.75203267,  0.48436183],
#        [-0.02539494,  0.67170453],
#        [-0.04014242,  0.67299948],
#        [-0.02591785, -1.12336409],
#        [-0.02279291, -1.85940982],
#        [-0.03004873,  0.67189936],
#        [-0.02547027,  0.67107865],
#        [-0.02548029,  0.66709453],
#        [-0.04578905,  0.66852602],
#        [-0.03920353,  0.6729718 ],
#        [-0.0427589 ,  0.67081706],
#        [-0.04797433,  0.66722579],
#        [-0.02331717,  0.66956159],
#        [-0.03555953,  0.66412152],
#        [-0.03834865,  0.67226161],
#        [-0.029416  ,  0.67028759],
# ...

# %%
df1.isnull().sum()
# Out:
# sha                            12080
# source_x                           0
# title                              9
# doi                             3143
# pmcid                           2163
# pubmed_id                      12770
# license                        11808
# abstract                        2591
# publish_time                   10896
# authors                          597
# journal                        11709
# Microsoft Academic Paper ID    28366
# WHO #Covidence                 28264
# has_full_text                  12080
# dtype: int64

# %%
df2=df1.drop(['sha','title','doi','pmcid','license','abstract','authors','journal','WHO #Covidence','has_full_text'],axis='columns')
df2.shape
# Out:
# (29500, 4)

# %%
df3=df2.drop(['source_x'],axis=1)
df3.shape
# Out:
# (29500, 3)

# %%
df4=df3.drop(['publish_time'],axis=1)
df4.shape
# Out:
# (29500, 2)

# %%
df5 = df4.dropna()
df5
# Out:
#        pubmed_id  Microsoft Academic Paper ID
# 0     32125455.0                 2.002765e+09
# 3     32093211.0                 1.776631e+08
# 4     32125453.0                 3.006643e+09
# 7     32105614.0                 2.627046e+09
# 12    32108862.0                 3.003549e+09
# ...          ...                          ...
# 1174  32139372.0                 2.775276e+09
# 1212  32057210.0                 2.377782e+09
# 1213  32078596.0                 2.185518e+09
# 1214  32096366.0                 2.349103e+09
# 1215  32105049.0                 3.005414e+09
#
# [399 rows x 2 columns]

# %%
df5
# Out:
#        pubmed_id  Microsoft Academic Paper ID
# 0     32125455.0                 2.002765e+09
# 3     32093211.0                 1.776631e+08
# 4     32125453.0                 3.006643e+09
# 7     32105614.0                 2.627046e+09
# 12    32108862.0                 3.003549e+09
# ...          ...                          ...
# 1174  32139372.0                 2.775276e+09
# 1212  32057210.0                 2.377782e+09
# 1213  32078596.0                 2.185518e+09
# 1214  32096366.0                 2.349103e+09
# 1215  32105049.0                 3.005414e+09
#
# [399 rows x 2 columns]

# %%
df5.isnull().sum()
# Out:
# pubmed_id                      0
# Microsoft Academic Paper ID    0
# dtype: int64

# %%
X_pca=pca.transform(X_scaled)
X_pca.shape
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-41-d6358184e28a> in <module>
# ----> 1 X_pca=pca.transform(X_scaled)
#       2 X_pca.shape
#
# ~\Anaconda3\lib\site-packages\sklearn\decomposition\base.py in transform(self, X)
#     123         >>> ipca.transform(X) # doctest: +SKIP
#     124         """
# --> 125         check_is_fitted(self, ['mean_', 'components_'], all_or_any=all)
#     126
#     127         X = check_array(X)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     912
#     913     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 914         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     915
#     916
#
# NotFittedError: This PCA instance is not fitted yet. Call 'fit' with appropriate arguments before using this method.

# %%
import numpy as np
np.nan_to_num(df5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-4126eb3967b7> in <module>
#       2 np.nan_to_num(df5)
#       3 pca=PCA(n_components=2,random_state=2)
# ----> 4 pca.fit(X_scaled)
#
# ~\Anaconda3\lib\site-packages\sklearn\decomposition\pca.py in fit(self, X, y)
#     339             Returns the instance itself.
#     340         """
# --> 341         self._fit(X)
#     342         return self
#     343
#
# ~\Anaconda3\lib\site-packages\sklearn\decomposition\pca.py in _fit(self, X)
#     380
#     381         X = check_array(X, dtype=[np.float64, np.float32], ensure_2d=True,
# --> 382                         copy=self.copy)
#     383
#     384         # Handle n_components==None
#
# ...

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2,random_state=2)
pca.fit(X_scaled)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=2,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
X_pca=pca.transform(X_scaled)
X_scaled.shape,X_pca.shape
# Out:
# ((399, 2), (399, 2))

# %%
plt.figure(figsize=(10,10))
plt.scatter(X_pca[:,0],X_pca[:,1],cmap='viridis')
plt.xlabel('First label Component')
plt.ylabel('Second label Component')
# Out:
# Text(0, 0.5, 'Second label Component')

# %%
help(pca)
# Out:
# Help on PCA in module sklearn.decomposition.pca object:
#
# class PCA(sklearn.decomposition.base._BasePCA)
#  |  PCA(n_components=None, copy=True, whiten=False, svd_solver='auto', tol=0.0, iterated_power='auto', random_state=None)
#  |
#  |  Principal component analysis (PCA)
#  |
#  |  Linear dimensionality reduction using Singular Value Decomposition of the
#  |  data to project it to a lower dimensional space. The input data is centered
#  |  but not scaled for each feature before applying the SVD.
#  |
#  |  It uses the LAPACK implementation of the full SVD or a randomized truncated
#  |  SVD by the method of Halko et al. 2009, depending on the shape of the input
#  |  data and the number of components to extract.
#  |
#  |  It can also use the scipy.sparse.linalg ARPACK implementation of the
#  |  truncated SVD.
#  |
#  |  Notice that this class does not support sparse input. See
#  |  :class:`TruncatedSVD` for an alternative with sparse data.
#  |
# ...

# %%
pca.explained_variance_ratio_
# Out:
# array([0.51685005, 0.48314995])

# %%
pca=PCA(n_components=2,random_state=2)
X_pca=pca.fit_transform(df5)
variance=pca.explained_variance_ratio_
variance
# Out:
# array([9.99889326e-01, 1.10674227e-04])

# %%
plt.bar(x=range(1,len(variance)+1),height=variance,width=0.5)
# Out:
# <BarContainer object of 2 artists>
